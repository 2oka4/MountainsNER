# %%
import pandas as pd
from transformers import BertTokenizer
import torch
from torch.utils.data import Dataset

# %% [markdown]
# The dataset was generated by using ChatGPT

# %%
train_df = pd.read_csv("mountains_labeled.csv")

# %%
train_df.head(20)
# Out:
#              word      Tag  sentence_num
# 0               I        O             1
# 1            have        O             1
# 2         visited        O             1
# 3           Mount        O             1
# 4            Fuji  B-mount             1
# 5       recently.        O             1
# 6           Mount        O             2
# 7      Kosciuszko  B-mount             2
# 8             and        O             2
# 9           Mount        O             2
# 10           Fuji  B-mount             2
# 11            are        O             2
# 12        popular        O             2
# 13  destinations.        O             2
# 14          Mount        O             3
# 15        Everest  B-mount             3
# 16             is        O             3
# 17          known        O             3
# 18            for        O             3
# 19            its        O             3

# %%
train_df['sentence'] = train_df[['word','Tag', 'sentence_num']].groupby(['sentence_num'])['word'].transform(lambda x: ' '.join(x)) #grouping data to form sentences
train_df['word_tags'] = train_df[['sentence_num','word','Tag']].groupby(['sentence_num'])['Tag'].transform(lambda x: ','.join(x))
train_df.head()
# Out:
#       word      Tag  sentence_num                             sentence  \
# 0        I        O             1  I have visited Mount Fuji recently.
# 1     have        O             1  I have visited Mount Fuji recently.
# 2  visited        O             1  I have visited Mount Fuji recently.
# 3    Mount        O             1  I have visited Mount Fuji recently.
# 4     Fuji  B-mount             1  I have visited Mount Fuji recently.
#
#            word_tags
# 0  O,O,O,O,B-mount,O
# 1  O,O,O,O,B-mount,O
# 2  O,O,O,O,B-mount,O
# 3  O,O,O,O,B-mount,O
# 4  O,O,O,O,B-mount,O

# %%
train_df.sentence_num.describe()
# Out:
# count    43002.000000
# mean      3003.352774
# std       1733.610047
# min          1.000000
# 25%       1499.000000
# 50%       3009.500000
# 75%       4504.000000
# max       6000.000000
# Name: sentence_num, dtype: float64

# %%
train_df = train_df[["sentence", "word_tags"]].drop_duplicates(subset="sentence").reset_index(drop=True) #1 row - 1 sentence

# %%
train_df.shape #there are 404 sentences in the dataset
# Out:
# (404, 2)

# %%
train_df.to_csv('mountains_preprocessed.csv', index=False) # saving preprocessed dataset
